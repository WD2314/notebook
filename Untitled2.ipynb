# %% [markdown]
# <a href="https://colab.research.google.com/github/WD2314/notebook/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 控制系统的状态空间表达式
#
# [TOC]
#
#
#
# ### 基本概念
#
# #### 状态变量
# 1. 足以完全表征系统运动状态的最小个数的一组变量
# 2. 选取不唯一个，个数 = 微分方程的阶数，等于系统独立储能元件的个数
# 3. 若确定n阶微分方程的唯一解，要知道n个独立的初始条件及一组状态变量在初始时刻t0值
# 4. 知道t=t0时刻的值，便能确定系统在t>=t0时的行为
#
# #### 状态矢量
#
# 各变量为其分量，$\boldsymbol{x}=\left[ \begin{array}{c}{x_{1}} \\ {x_{2}} \\ {\vdots} \\ {x_{n}}\end{array}\right]$
#
#
#
# #### 状态空间
#
# 1. 以状态变量为
#
#
#
# #### 状态方程
#
# $\dot{x}=A x+B u$
#
#
# <img src="C:\Users\Mr.W Dr.D\Desktop\现控\assets\1556435747414.png" style="width:100px height:100px" />
#
# #### 输出方程
#
# $y=C x+D u$
#
#
#
# #### 状态空间表达式
#
# $\dot{x}=A x+B$
# $y=C x$
#
# $\boldsymbol{x}=\left[ \begin{array}{c}{x_{1}} \\ {x_{2}} \\ {\vdots} \\ {x_{n}}\end{array}\right]$ n 维状态矢量
#
#
#
# #### 状态空间表达式的系统框图
#
#
#
#
#
# ### 模拟结构图
#
# #### 步骤
#
# 1. 积分器数目=状态变量数	画在适当位置
# 2. 积分器的输出=某个变量数
# 3. 由状态方程和输出方程，画相应的加法器和比例器
#
# #### 常用图例
#
#
#
# ### 建立方法
#
# #### 从系统框图
#
#
#
# #### 从系统的机理
#
#
#
# #### 从高阶微分，传递函数
#
# （描述系统动态过程的）
#
# 1. 微分方程中不含输入信号导数项,传递函数无零点
#
# 一般情况下，n 阶微分方程为：
# $$
# y^{(n)}+a_{n-1} y^{(n-1)}+\cdots+a_{1} \dot{y}+a_{0} y=b_{0} u
# $$
# 选择状态变量如下：
# $$
# \begin{array}{l}{x_{1}=y} \\ {\dot{x}_{1}=x_{2}=\dot{y}} \\ {\dot{x}_{2}=x_{3}=\dot{y}} \\ {\dot{x}_{n-1}=x_{n}=y^{(n-1)}} \\ {\dot{x}_{n}=y^{(n)}=-a_{0} x_{1}-a_{1} x_{2}-\cdots--a_{n-1} x_{n}+b_{0} u}\end{array}
# $$
# 矩阵形式：![1556444867072](C:\Users\Mr.W Dr.D\Desktop\现控\assets\1556444867072.png)
#
#
#
# 2. 微分方程中含有输入信号导数项  传递函数有零点
#
#    1. 待定系数法
#
#       一般情况下，n 阶微分方程为：
#       $$
#       y^{(n)}+a_{n-1} y^{(n-1)}+\cdots+a_{1} \dot{y}+a_{0} y=b_{n} u^{(n)}+b_{n-1} u^{(n-1)}+\cdots+b_{1} \dot{u}+b_{0} u
#       $$
#       选择 n 个状态变量为
#       $$
#       \begin{aligned} x_{1} &=y-\beta_{0} u \\ x_{2} &=\dot{x}_{1}-\beta_{1} u \\ x_{3} &=\dot{x}_{2}-\beta_{2} u \\ x_{n} &=\dot{x}_{n-1}-\beta_{n-1} u \end{aligned}
#       $$
#
#       $$
#       y=\left[ \begin{array}{cc}{1} & {0} & {\cdots} & {0}\end{array}\right] \left[ \begin{array}{c}{x_{1}} \\ {\vdots} \\ {x_{n}}\end{array}\right]+\beta_{0} u
#       $$
#
#       $$
#       \begin{aligned} \beta_{0} &=b_{3} \\ \beta_{1} &=b_{2}-a_{2} \beta_{0} \\ \beta_{2} &=b_{1}-a_{1} \beta_{0}-a_{2} \beta_{1} \\ \beta_{3} &=b_{0}-a_{0} \beta_{0}-a_{1} \beta_{1}-a_{2} \beta_{2} \end{aligned}
#       $$
#
#       系统方程为
#
#       ![1556445920728](C:\Users\Mr.W Dr.D\Desktop\现控\assets\1556445920728.png)
#
#    2. 辅助变量法
#
#       ![1556446248335](C:\Users\Mr.W Dr.D\Desktop\现控\assets\1556446248335.png)
#
#       ![1556446281561](C:\Users\Mr.W Dr.D\Desktop\现控\assets\1556446281561.png)
#
#       ![1556446298855](C:\Users\Mr.W Dr.D\Desktop\现控\assets\1556446298855.png)
#
#
#
#
#
# ### 状态矢量的线性变换
#
# #### 系统状态空间表达式的非唯一性
#
#
#
#
#
# #### 系统特征值的不变性及系统的不变量
#
#
#
#
#
# #### 状态空间表达式—>约旦标准型
#
#
#
# ### 状态空间表达式—>传递函数阵
#
# ### 离散时间系统
